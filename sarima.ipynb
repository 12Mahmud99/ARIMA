# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import utils

from statsmodels.tsa.statespace.sarimax import SARIMAX
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 import torch
#       5 import utils
# ----> 7 from statsmodels.tsa.sarima.model import SARIMA
#
# ModuleNotFoundError: No module named 'statsmodels.tsa.sarima'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
x = torch.randn(100).to(device)
series = pd.Series(x.detach().cpu().numpy())

model = SARIMAX(series, order=(1, 0, 1))
result = model.fit()

# %%
#print(result.summary())

# %%
utils.plot_arima_simulated_forecast(series, result,t=50)
